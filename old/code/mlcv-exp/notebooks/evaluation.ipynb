# %%
# Reload the notebook automatically
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import

# %%
import sys
from pathlib import Path
from IPython.display import clear_output

WORK_DIR = Path(Path.cwd()).parent
sys.path.append(str(WORK_DIR))
from src import ROOT, parse
from src.eval_helper import get_eval_helper

# %% [markdown]
# # Setup

# %%
dataset = 'fpha'
model = 'hpo_bbox_ar_SL'
exp = 'exp1'
epoch = 200
split = 'test'

cfg_dir = 'mlcv-exp/data/cfg/'
cfg_name = '{}_{}_{}.cfg'.format(dataset, model, exp)
cfg = parse(Path(ROOT)/cfg_dir/model/cfg_name)
eval_helper = get_eval_helper(cfg, epoch, split)
print(eval_helper.get_len())
# Out:
# test dataset: 100%|██████████| 575/575 [00:11<00:00, 49.66it/s]
# 44034

# %%
dataloader = 1
prediction = 1

# %% [markdown]
# # Dataloader

# %%
if dataloader:
    eval_helper.data_load  = next(iter(eval_helper.dataloader))

# %%
if dataloader:
    idx = 0
    eval_helper.visualize_dataloader(idx)
else:
    clear_output
# Out:
# /mnt/4TB/aaron/First_Person_Action_Benchmark/Video_files_rsz/Subject_2/sprinkle/3/color/color_0063.jpeg
# Action: sprinkle spoon
# [0.47569752 0.81699896 0.21822916 0.30833334]

# %%
if dataloader:
    eval_helper.visualize_multi_dataloader()
else:
    clear_output

# %% [markdown]
# # Visualize One Prediction

# %%
if prediction:
    idx = 15426
    eval_helper.visualize_one_prediction(idx)
else:
    clear_output
# Out:
# /mnt/4TB/aaron/First_Person_Action_Benchmark/Video_files_rsz/Subject_2/charge_cell_phone/1/color/color_0000.jpeg
# [0. 0. 0. 0. 0.]
# Ground-truth action + object: charge_cell_phone + cell_charger
# Predicted action + object: charge_cell_phone + cell_charger

# %% [markdown]
# # Metrics

# %%
if prediction:
    eval_helper.eval()
else:
    clear_output
# Out:
# Top1 Action Accuracy 0.7500794840350639
# Top1 Object Accuracy 0.8530680837534632
# Top1 Both Accuracy 0.7308443475496208
# ------------------------------
# Top5 Action Accuracy 0.9818095108325385
# Top5 Object Accuracy 0.9975700594994776
# Top5 Both Accuracy 0.9815369941408911
# ------------------------------
# Top1 Mean-Class Action Accuracy 0.7362362933957252
# Top1 Mean-Class Object Accuracy 0.7954892282922873
# Top1 Mean-Class Both Accuracy 0.7178987489612036
# ------------------------------
# Top5 Mean-Class Action Accuracy 0.9818394402895062
# Top5 Mean-Class Object Accuracy 0.9950404385659138
# Top5 Mean-Class Both Accuracy 0.9816200192117012
# ------------------------------
# Recall: 0.9984784484716356
# Avg_IOU: 0.8344109301794098
# Worst Bbox id: 15426
